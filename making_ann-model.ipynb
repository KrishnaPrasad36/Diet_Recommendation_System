# %%
import pandas as pd
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten

from tensorflow.keras import layers

# %%
df=pd.read_csv('update_data_for_ann_by_removing_negative_value.csv')

# %%
df
# Out:
#                               name  calories  FatContent  SaturatedFatContent  \
# 0       Seasoned Goldfish Crackers  30929.55     1567.03               574.28
# 1       Seasoned Goldfish Crackers  30928.70     1566.05               579.12
# 2       Seasoned Goldfish Crackers  30935.97     1559.81               572.48
# 3       Seasoned Goldfish Crackers  30928.59     1562.37               575.96
# 4       Seasoned Goldfish Crackers  30934.20     1565.55               578.72
# ...                            ...       ...         ...                  ...
# 999995         Beets in Sour Cream    106.08        9.27                 0.00
# 999996         Beets in Sour Cream    109.99        3.36                 2.15
# 999997         Beets in Sour Cream    109.48       10.34                 0.00
# 999998         Beets in Sour Cream    109.24        8.48                 0.00
# 999999         Beets in Sour Cream    104.12        5.55                 0.00
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y_train_encoder=encoder.fit_transform(df['name'])

# %%
df['label_name']=y_train_encoder

# %%
df[['name','label_name']]
# Out:
#                               name  label_name
# 0       Seasoned Goldfish Crackers       15943
# 1       Seasoned Goldfish Crackers       15943
# 2       Seasoned Goldfish Crackers       15943
# 3       Seasoned Goldfish Crackers       15943
# 4       Seasoned Goldfish Crackers       15943
# ...                            ...         ...
# 999995         Beets in Sour Cream        1863
# 999996         Beets in Sour Cream        1863
# 999997         Beets in Sour Cream        1863
# 999998         Beets in Sour Cream        1863
# 999999         Beets in Sour Cream        1863
#
# [1000000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop('name',axis=1),df['name'],test_size=0.2,random_state=42)

# %%
x_train
# Out:
#         calories  FatContent  SaturatedFatContent  CholesterolContent  \
# 566853    262.12       18.05                 6.96               10.57
# 382311    351.32       16.45                12.63               51.74
# 241519    450.10       19.88                 4.80               48.53
# 719220    203.15       13.16                 6.50               18.50
# 905718    144.69        4.50                 0.48               83.76
# ...          ...         ...                  ...                 ...
# 259178    433.84        9.03                 0.97              243.92
# 365838    357.73       16.43                 5.10              163.63
# 131932    581.26       32.75                13.57               78.08
# 671155    215.66        3.41                 4.30               29.10
# 121958    606.45        9.51                 3.50               13.44
#
#         SodiumContent  CarbohydrateContent  FiberContent  SugarContent  \
# ...

# %%
scaler=StandardScaler()
scaler.fit(x_train)
x_train_scaled=scaler.transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
model = Sequential()
model.add(Flatten(input_shape=(x_train.shape[1],)))
model.add(Dense(20000,activation='relu')),
model.add(Dense(2000,activation='relu'))
model.add(Dense(20000,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 9)                 0
#
#  dense_3 (Dense)             (None, 20000)             200000
#
#  dense_4 (Dense)             (None, 2000)              40002000
#
#  dense_5 (Dense)             (None, 20000)             40020000
#
# ...
# Total params: 80222000 (306.02 MB)
# Trainable params: 80222000 (306.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),optimizer='Adam',metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),optimizer='Adam',metrics=['accuracy'])
#
# NameError: name 'tf' is not defined

# %%
history=model.fit(x_train_scaled,y_train,epochs=100,validation_split=0.2,batch_size=50,verbose=1)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 history=model.fit(x_train_scaled,y_train,epochs=100,validation_split=0.2,batch_size=50,verbose=1)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
# ...
